# %% [markdown]
# This activity asks you to build several different date-time calculators, each of which performs a different calculation. Each calculator will accept appropriate user input for that calculator and perform the specified calculation using that input.
#
# For each calculator:
#
# You may define the format that the user should use to enter the values, but that format must be very clear to the user.
# If the user does not enter data in the expected format, the program should display an appropriate message and prompt the user to try again.
# Create appropriate functions, classes, and methods to simplify your code.
# The user must be able to clear all input at any time to start over again.
# The user must be able to exit the program at any time.
# User input can be simplified by breaking it up into discrete values. For example, instead of asking the user to enter a complete date (which could have a variety of formats), the program can prompt for separate date, month, and year values. This creates more work on the backend because your program will have to be able to convert the distinct values into a date, but it can make the program less error-prone.
#
# Put all of the following calculators in a single program and allow the user to choose the one they wish to use.

# %% [markdown]
# Calculator 1: Time Duration
# Add or subtract two different lengths of time.
#
# The calculator must include days, hours, minutes, and seconds.
# The user must be able to specify addition or subtraction between the two different input times.
# The output must display the results in multiple ways:
# the number of days, hours, minutes, and seconds
# the number of days
# the number of hours
# the number of minutes
# the number of seconds
# For example, if the user enters one value of 3 days, 5 hours, 15 minutes, and 0 seconds, and adds a value of 7 days, 20 hours, 50 minutes and 10 seconds, the result will be:
#
# 11 days 2 hours 2 minutes 10 seconds
# 11.084838 days
# 266.03611 hours
# 15,962.167 minutes
# 957,730 seconds

# %% [markdown]
# Challenge
# After the initial version of the calculator works as expected, include weeks as an additional unit, for the input values and the output result.

# %%
# Veronica Smigielski 02/05/2021
import datetime

print("First value input: ")
user_day1 = int(input("Enter a day: "))
        
user_hour1 = int(input("Enter the hour: "))
if user_hour1 < 0 and user_hour1 > 23:
    user_hour1 = int(input("Please enter a valid hour: "))
user_minute1 = int(input("Enter the minute: "))
if user_minute1 < 0 and user_minute1 > 59:
    user_minute1 = int(input("Please enter a valid minute: "))
user_second1 = int(input("Enter the second: "))
if user_second1 < 0 and user_second1 > 59:
    user_second1 = int(input("Please enter a valid second: ")) 
        
print("Second value input: ")
user_day2 = int(input("Enter a day: "))
        
user_hour2 = int(input("Enter the hour: "))
if user_hour2 < 0 and user_hour2 > 23:
    user_hour2 = int(input("Please enter a valid hour: "))
user_minute2 = int(input("Enter the minute: "))
if user_minute2 < 0 and user_minute2 > 59:
    user_minute2 = int(input("Please enter a valid minute: "))
user_second2 = int(input("Enter the second: "))
if user_second2 < 0 and user_second2 > 59:
    user_second2 = int(input("Please enter a valid second: ")) 

user_input = input("Would you like to add or subtract these values?\n")

sum_of_seconds = 0
extra_sec = 0
sum_of_minutes = 0
extra_min = 0
sum_of_hours = 0
extra_hours = 0
sum_of_days = 0

if user_input.lower() == "add":
    # Converts the values that are above the clock's allowance
    sum_of_seconds = user_second1 + user_second2
    if sum_of_seconds >= 60:
        extra_sec = sum_of_seconds - 60
        sum_of_minutes += 1
    sum_of_minutes += user_minute1 + user_minute2
    if sum_of_minutes >= 60:
        extra_min = sum_of_minutes - 60
        sum_of_hours += 1
    sum_of_hours += user_hour1 + user_hour2
    if sum_of_hours >= 24:
        extra_hours = sum_of_hours - 24
        sum_of_days += 1
    sum_of_days += user_day1 + user_day2
    
    # Checks the input for proper output
    if sum_of_days > 1 and sum_of_hours > 1 and sum_of_minutes > 1 and sum_of_seconds > 1:
        print(sum_of_days, "days", extra_hours, "hours", extra_min, "minutes", sum_of_seconds, "seconds")
    elif sum_of_days > 1 and sum_of_hours > 1 and sum_of_minutes > 1 and sum_of_seconds == 1:
        print(sum_of_days, "days", extra_hours, "hours", extra_min, "minutes", sum_of_seconds, "second")
    elif sum_of_days > 1 and sum_of_hours > 1 and sum_of_minutes == 1 and sum_of_seconds > 1:
        print(sum_of_days, "days", extra_hours, "hours", extra_min, "minute", sum_of_seconds, "seconds")
    elif sum_of_days > 1 and sum_of_hours == 1 and sum_of_minutes > 1 and sum_of_seconds > 1:
        print(sum_of_days, "days", extra_hours, "hour", extra_min, "minutes", sum_of_seconds, "seconds")
    elif sum_of_days == 1 and sum_of_hours > 1 and sum_of_minutes > 1 and sum_of_seconds > 1:
        print(sum_of_days, "day", extra_hours, "hours", extra_min, "minutes", sum_of_seconds, "seconds")
    elif sum_of_days == 1 and sum_of_hours > 1 and sum_of_minutes > 1 and sum_of_seconds == 1:
        print(sum_of_days, "day", extra_hours, "hours", extra_min, "minutes", sum_of_seconds, "second")
    elif sum_of_days > 1 and sum_of_hours == 1 and sum_of_minutes > 1 and sum_of_seconds == 1:
        print(sum_of_days, "days", extra_hours, "hour", extra_min, "minutes", sum_of_seconds, "second")
    elif sum_of_days == 1 and sum_of_hours == 1 and sum_of_minutes > 1 and sum_of_seconds == 1:
        print(sum_of_days, "day", extra_hours, "hour", extra_min, "minutes", sum_of_seconds, "second")
    elif sum_of_days > 1 and sum_of_hours == 1 and sum_of_minutes == 1 and sum_of_seconds > 1:
        print(sum_of_days, "days", extra_hours, "hour", extra_min, "minute", sum_of_seconds, "seconds")
    elif sum_of_days > 1 and sum_of_hours > 1 and sum_of_minutes == 1 and sum_of_seconds == 1:
        print(sum_of_days, "days", extra_hours, "hours", extra_min, "minute", sum_of_seconds, "second")
    elif sum_of_days > 1 and sum_of_hours == 1 and sum_of_minutes == 1 and sum_of_seconds == 1:
        print(sum_of_days, "days", extra_hours, "hour", extra_min, "minute", sum_of_seconds, "second")
    elif sum_of_days == 1 and sum_of_hours == 1 and sum_of_minutes == 1 and sum_of_seconds == 1:
        print(sum_of_days, "day", extra_hours, "hour", extra_min, "minute", sum_of_seconds, "second")
    
    # Convert overall seconds into a decimal out of a day
    hours_in_sec = extra_hours * 3600
    minutes_in_sec = extra_min * 60
    seconds_overall = hours_in_sec + minutes_in_sec + extra_sec
    seconds_in_day = seconds_overall / 86400
    days_seconds = sum_of_days + seconds_in_day
    
    # Check to show proper output
    if days_seconds > 1:    
        print(days_seconds, "days")
    else:    
        print(days_seconds, "day")
    
    # Convert mins&seconds to hours as a decimal
    days_in_hours = sum_of_days * 24
    minutes_in_hours = extra_min / 60
    seconds_in_hours = extra_sec / 3600
    hours_overall = minutes_in_hours + seconds_in_hours
    days_hours = days_in_hours + extra_hours + hours_overall
    
    # Check to show proper input
    if days_hours > 1:
        print(days_hours, "hours")
    else:
        print(days_hours, "hour")
        
    # Converts items to minutes
    days_in_min = sum_of_days * 1440
    hours_in_min = extra_hours * 60
    seconds_in_min = sum_of_seconds / 60
    minutes_overall = days_in_min + hours_in_min + extra_min + seconds_in_min
    minutes_commas = "{:,}".format(minutes_overall)
    
    # Check to show proper input
    if minutes_overall > 1:
        print(minutes_commas, "minutes")
    else: 
        print(minutes_commas, "minute")
        
    # Converts items to minutes
    days_in_sec = sum_of_days * 86400
    hours_in_sec = extra_hours * 3600
    min_in_sec = extra_min * 60
    sec_overall = days_in_sec + hours_in_sec + min_in_sec + sum_of_seconds
    sec_commas = "{:,}".format(sec_overall)
    
    # Check to show proper input
    if sec_overall > 1:
        print(sec_commas, "seconds")
    else:
        print(sec_commas, "second")
    
elif user_input.lower() == "subtract":
    seconds_day1 = user_day1 * 86400
    seconds_hour1 = user_hour1 * 3600
    seconds_minute1 = user_minute1 * 60
    overall_user_seconds1 =  seconds_day1 + seconds_hour1 + seconds_minute1 + user_second1
    
    seconds_day2 = user_day2 * 86400
    seconds_hour2 = user_hour2 * 3600
    seconds_minute2 = user_minute2 * 60
    overall_user_seconds2 =  seconds_day2 + seconds_hour2 + seconds_minute2 + user_second2
    
    sub_seconds = 0
    
    if overall_user_seconds1 > overall_user_seconds2:
        sub_seconds = overall_user_seconds1 - overall_user_seconds2
    else: 
        sub_seconds = overall_user_seconds2 - overall_user_seconds1
    
    overall_seconds = sub_seconds
    seconds_comma = "{:,}".format(overall_seconds)
    
    sum_of_days = 0
    sum_of_hours = 0
    sum_of_min = 0
    
    while sub_seconds >= 86400:
        sub_seconds -= 86400
        sum_of_days += 1
    while sub_seconds >= 3600:
        sub_seconds -= 3600
        sum_of_hours += 1
    while sub_seconds >= 60:
        sub_seconds -= 60
        sum_of_min += 1
    
    print(sum_of_days, "days", sum_of_hours, "hours", sum_of_min, "minutes", sub_seconds, "seconds")
    
    hours_in_days = sum_of_hours * 3600
    min_in_days = sum_of_min * 60
    seconds_in_days = sub_seconds
    seconds_overall = hours_in_days + min_in_days + seconds_in_days
    seconds_in_dec = seconds_overall / 86400
    days_seconds = sum_of_days + seconds_in_dec
    
    if days_seconds > 1:
        print(days_seconds, "days")
    else:
        print(days_seconds, "day")
        
    days_in_hours = sum_of_days * 24
    hours_dec = (min_in_days + seconds_in_days) / 3600
    days_hours = days_in_hours + sum_of_hours + hours_dec
    
    if days_hours > 1:
        print(days_hours, "hours")
    else:
        print(days_hours, "hour")
        
    days_in_min = sum_of_days * 1440
    hours_in_min = sum_of_hours * 60
    sec_dec = seconds_in_days / 60
    overall_min = days_in_min + hours_in_min + sum_of_min + sec_dec
    min_commas = "{:,}".format(overall_min)
    
    if overall_min > 1:
        print(min_commas, "minutes")
    else:
        print(min_commas, "minute")
    
    if overall_seconds > 1:
        print(seconds_comma, "seconds")
    else: 
        print(seconds_comma, "second")
        
else: 
    print("That was not a valid option")
# Out:
# First value input:
# Enter a day: 7
# Enter the hour: 20
# Enter the minute: 50
# Enter the second: 10
# Second value input:
# Enter a day: 3
# Enter the hour: 5
# Enter the minute: 15
# Enter the second: 0
# Would you like to add or subtract these values?
# subtract
# 4 days 15 hours 35 minutes 10 seconds
# 4.649421296296296 days
# 111.58611111111111 hours
# 6,695.166666666667 minutes
# 401,710 seconds

# %%
def time_duration(duration1, duration2, addition):
        
        day1 = duration1[0]
        hour1 = duration1[1]
        min1 = duration1[2]
        sec1 = duration1[3]
        
        day2 = duration2[0]
        hour2 = duration2[1]
        min2 = duration2[2]
        sec2 = duration2[3]
        
        duration_sec = 0
        duration_min = 0
        duration_hour = 0
        duration_day = 0
        
        if addition:
            duration_sec += sec1 + sec2
            
            if duration_sec > 60:
                duration_sec = duration_sec - 60
                duration_min = 1 
            
            duration_min += min1 + min2
            
            if duration_min > 60:
                duration_min = duration_min - 60
                duration_hour = 1
                
            duration_hour += hour1 + hour2
            
            if duration_hour > 24:
                duration_hour = duration_hour - 24
                duration_day = 1
            
            duration_day += day1 + day2
        
        else:
            duration_sec += sec1 - sec2
            
            if duration_sec < 0:
                duration_sec = duration_sec + 60
                duration_min = -1 
            
            duration_min += min1 - min2
            
            if duration_min < 0:
                duration_min = duration_min + 60
                duration_hour = -1
                
            duration_hour += hour1 - hour2
            
            if duration_hour < 0:
                duration_hour = duration_hour + 24
                duration_day = -1
            
            duration_day += day1 - day2
            
            
print(duration_day, "days,", duration_hour, "hours,", duration_min, "minutes,", duration_sec, "seconds.")
print(duration_day + duration_hour / 24 + duration_min / 1440 + duration_sec / 86400, "days")
print(duration_day * 24 + duration_hour + duration_min / 60 + duration_sec / 3600, "hours")
print(duration_day * 1440 + duration_hour * 60 + duration_min + duration_sec / 60, "minutes")
print(duration_day * 86400 + duration_hour * 3600 + duration_min * 60 + duration_sec, "seconds")

# %% [markdown]
# Calculator 2: Add or Subtract Time from a Date
# Given a date and time, add or subtract an input length of time and display the date and time of the result.
#
# The calculator must include days, hours, minutes, and seconds, for input and output.
# The user must be able to choose between addition and subtraction.
# For example, if the user enters December 1, 2021, 12:04:00 PM, and wants to subtract five days, 3 hours, and 30 minutes, the result would be November 25, 2021, 08:34:00 PM.

# %% [markdown]
# Challenge
# Include the day of the week (Monday, Tuesday, etc.) in the output.

# %%
# Veronica Smigielski 02/05/2021
import datetime
import math

user_year = int(input("Enter a year: "))
if user_year < 1900 or user_year > 2100:
    user_year = int(input("Please enter a valid year: "))
user_month = int(input("Enter a month: "))
if user_month < 1 or user_month > 12:
    user_month = int(input("Please enter a valid month: "))
user_day = int(input("Enter a day: "))
if user_month == 1 or user_month == 3 or user_month == 5 or user_month == 7 or user_month == 8 or user_month == 10 or user_month == 12:
    if user_day < 1 or user_day > 31:
        user_day = int(input("Please enter a valid day: "))
elif user_month == 2:
    if user_day < 1 or user_day > 28:
        user_day = int(input("Please enter a valid day: "))
else:
    if user_day < 1 or user_day > 30:
        user_day = int(input("Please enter a valid day: "))
        
user_hour = int(input("Enter the current hour: "))
if user_hour < 0 or user_hour > 23:
    user_hour = int(input("Please enter a valid hour: "))
user_minute = int(input("Enter the current minute: "))
if user_minute < 0 or user_minute > 59:
    user_minute = int(input("Please enter a valid minute: "))
user_second = int(input("Enter the current second: "))
if user_second < 0 or user_second > 59:
    user_second = int(input("Please enter a valid second: "))

t1 = datetime.datetime(user_year, user_month, user_day, user_hour, user_minute, user_second)

base = datetime.datetime.today()

user_day2 = int(input("Enter a day: "))
user_hour2 = int(input("Enter the hour: "))
user_minute2 = int(input("Enter the minute: "))
user_second2 = int(input("Enter the second: "))

user_input = input("Would you like to add, subtract, or quit?\n")

if user_input.lower() != "quit":
    if user_input.lower() == "add":
        t2 = (t1 + datetime.timedelta(days=user_day2, hours=user_hour2, minutes=user_minute2, seconds=user_second2))
        t3 = str(t2)
        (d,t4) = t3.split()
        (year,month,day) = d.split("-")
        if t2.month == 1:
            print("January " + day + ", " + year + ",", t4)
        elif t2.month == 2:
            print("February " + day + ", " + year + ",", t4)
        elif t2.month == 3:
            print("March " + day + ", " + year + ",", t4)
        elif t2.month == 4:
            print("April " + day + ", " + year + ",", t4)
        elif t2.month == 5:
            print("May " + day + ", " + year + ",", t4)
        elif t2.month == 6:
            print("June " + day + ", " + year + ",", t4)
        elif t2.month == 7:
            print("July " + day + ", " + year + ",", t4)
        elif t2.month == 8:
            print("August " + day + ", " + year + ",", t4)
        elif t2.month == 9:
            print("September " + day + ", " + year + ",", t4)
        elif t2.month == 10:
            print("October " + day + ", " + year + ",", t4)
        elif t2.month == 11:
            print("November " + day + ", " + year + ",", t4)
        elif t2.month == 12:
            print("December " + day + ", " + year + ",", t4)
    elif user_input.lower() == "subtract":
        t2 = (t1 - datetime.timedelta(days=user_day2, hours=user_hour2, minutes=user_minute2, seconds=user_second2))
        t3 = str(t2)
        (d,t4) = t3.split()
        (year,month,day) = d.split("-")
        if t2.month == 1:
            print("January " + day + ", " + year + ",", t4)
        elif t2.month == 2:
            print("February " + day + ", " + year + ",", t4)
        elif t2.month == 3:
            print("March " + day + ", " + year + ",", t4)
        elif t2.month == 4:
            print("April " + day + ", " + year + ",", t4)
        elif t2.month == 5:
            print("May " + day + ", " + year + ",", t4)
        elif t2.month == 6:
            print("June " + day + ", " + year + ",", t4)
        elif t2.month == 7:
            print("July " + day + ", " + year + ",", t4)
        elif t2.month == 8:
            print("August " + day + ", " + year + ",", t4)
        elif t2.month == 9:
            print("September " + day + ", " + year + ",", t4)
        elif t2.month == 10:
            print("October " + day + ", " + year + ",", t4)
        elif t2.month == 11:
            print("November " + day + ", " + year + ",", t4)
        elif t2.month == 12:
            print("December " + day + ", " + year + ",", t4)
    else:
        print("That was not a valid input.")
# Out:
# Enter a year: 2021
# Enter a month: 12
# Enter a day: 1
# Enter the current hour: 12
# Enter the current minute: 4
# Enter the current second: 0
# Enter a day: 5
# Enter the hour: 3
# Enter the minute: 30
# Enter the second: 0
# Would you like to add, subtract, or quit?subtract
# November 26, 2021, 08:34:00

# %% [markdown]
# Calculator 3: Age Calculator
# Given a start date and an end date, calculate the amount of time passed between the dates, displayed in years, months, days, hours, minutes and seconds.
#
# For example, given the start date September 1, 1994 and the end date December 1, 2021, the results would be:
#
# 25 years 3 months 10 days
# 303 months 10 days
# 1318 weeks 6 days
# 9,232 days
# 221,568 hours
# 13,294,080 minutes
# 797,644,800 seconds

# %% [markdown]
# Challenge
# Update the calculator to include a specific time with each date.

# %%
# Veronica Smigielski 02/05/2021
import math
import datetime as dt

user_year = int(input("Enter a year: "))
if user_year < 1900 or user_year > 2100:
    user_year = int(input("Please enter a valid year: "))
user_month = int(input("Enter a month: "))
if user_month < 1 or user_month > 12:
    user_month = int(input("Please enter a valid month: "))
user_day = int(input("Enter a day: "))
if user_month == 1 or user_month == 3 or user_month == 5 or user_month == 7 or user_month == 8 or user_month == 10 or user_month == 12:
    if user_day < 1 or user_day > 31:
        user_day = int(input("Please enter a valid day: "))
elif user_month == 2:
    if user_day < 1 or user_day > 28:
        user_day = int(input("Please enter a valid day: "))
else:
    if user_day < 1 or user_day > 30:
        user_day = int(input("Please enter a valid day: "))
user_hour = int(input("Enter the current hour: "))
if user_hour < 0 or user_hour > 23:
    user_hour = int(input("Please enter a valid hour: "))
user_minute = int(input("Enter the current minute: "))
if user_minute < 0 or user_minute > 59:
    user_minute = int(input("Please enter a valid minute: "))
user_second = int(input("Enter the current second: "))
if user_second < 0 or user_second > 59:
    user_second = int(input("Please enter a valid second: "))

user_year2 = int(input("Enter a year: "))
if user_year2 < 1900 or user_year2 > 2100:
    user_year2 = int(input("Please enter a valid year: "))
user_month2 = int(input("Enter a month: "))
if user_month2 < 1 or user_month2 > 12:
    user_month2 = int(input("Please enter a valid month: "))
user_day2 = int(input("Enter a day: "))
if user_month2 == 1 or user_month2 == 3 or user_month2 == 5 or user_month2 == 7 or user_month2 == 8 or user_month2 == 10 or user_month2 == 12:
    if user_day2 < 1 or user_day2 > 31:
        user_day2 = int(input("Please enter a valid day: "))
elif user_month2 == 2:
    if user_day2 < 1 or user_day2 > 28:
        user_day2 = int(input("Please enter a valid day: "))
else:
    if user_day2 < 1 or user_day2 > 30:
        user_day2 = int(input("Please enter a valid day: "))
user_hour2 = int(input("Enter the current hour: "))
if user_hour2 < 0 or user_hour2 > 23:
    user_hour2 = int(input("Please enter a valid hour: "))
user_minute2 = int(input("Enter the current minute: "))
if user_minute2 < 0 or user_minute2 > 59:
    user_minute2 = int(input("Please enter a valid minute: "))
user_second2 = int(input("Enter the current second: "))
if user_second2 < 0 or user_second2 > 59:
    user_second2 = int(input("Please enter a valid second: "))
    
a = dt.datetime(user_year,user_month,user_day,user_hour,user_minute,user_second)
b = dt.datetime(user_year2,user_month2,user_day2,user_hour2,user_minute2,user_second2)

overall_seconds = math.trunc((b-a).total_seconds())
overall_minutes = math.trunc(overall_seconds / 60)
overall_hours = math.trunc(overall_minutes / 60)
overall_days = math.trunc(overall_hours / 24)
overall_weeks = math.trunc(overall_days / 7)
no_week_days = overall_days % 7
overall_months_year = (math.trunc(overall_days / 365.2425)) * 12 
no_month_days = overall_days % 365.2425
extra_months = math.trunc(no_month_days / (365/12))
no_day_months = no_month_days % (365/12)
overall_months = overall_months_year + extra_months
overall_years = math.trunc(overall_days / 365.2425)

weeks_commas = "{:,}".format(overall_weeks)
days_commas = "{:,}".format(overall_days)
hours_commas = "{:,}".format(overall_hours)
minutes_commas = "{:,}".format(overall_minutes)
seconds_commas = "{:,}".format(overall_seconds)

print(overall_years, "years", extra_months, "months", math.trunc(no_day_months), "days")
print(overall_months, "months", math.trunc(no_day_months), "days")
print(weeks_commas, "weeks", no_week_days, "days")
print(days_commas, "days")
print(hours_commas, "hours")
print(minutes_commas, "minutes")
print(seconds_commas, "seconds")
# Out:
# Enter a year: 1994
# Enter a month: 9
# Enter a day: 1
# Enter the current hour: 23
# Enter the current minute: 59
# Enter the current second: 59
# Enter a year: 2019
# Enter a month: 12
# Enter a day: 11
# Enter the current hour: 23
# Enter the current minute: 59
# Enter the current second: 59
# 25 years 3 months 9 days
# 303 months 9 days
# 1,318 weeks 6 days
# 9,232 days
# 221,568 hours
# 13,294,080 minutes
# 797,644,800 seconds

# %% [markdown]
# Include your name and a current date as a comment on the first line of code.
# Use meaningful names for all named objects (such as classes and variables) so that another developer can read the code easily.
# Requests for user input should be designed to reduce input errors.
# All prompts and output to the user must use correct spelling and grammar.
# Input errors must be handled gracefully and allow the user to reenter the data.
