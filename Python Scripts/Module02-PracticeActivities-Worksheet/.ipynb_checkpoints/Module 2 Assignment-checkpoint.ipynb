# %% [markdown]
# This exercise asks you to combine the Python skills you have learned into a single application. We will start with a paragraph of text and end up with a frequency count of the distinct words in that text.
#
# It includes the following steps:
#
# Convert a string to lowercase characters.
# Split the lowercase string into individual words.
# Count the number of words in the lowercase string.
# Determine the number of distinct words in the lowercase string.
# Calculate the number of times each word appears in the lowercase string.
# Remove the punctuation from the lowercase string.
# Perform a count analysis on the text without punctuation characters.

# %%
import string

# Declare a string
s = """Imagine a vast sheet of paper on which straight Lines, Triangles,
Squares, Pentagons, Hexagons, and other figures, instead of remaining fixed
in their places, move freely about, on or in the surface, but without the
power of rising above or sinking below it, very much like shadows - only hard
and with luminous edges - and you will then have a pretty correct notion of
my country and countrymen. Alas, a few years ago, I should have said "my
universe": but now my mind has been opened to higher views of things."""

# lowercase the string
s_lower = s.lower()

# Split the string into a list of singular words
words = list(s_lower.split())

# Make a new set to hold the words (no duplicates)
words_set = set()

# Initialize count for list
count_list = 0

# Use a for loop to get the list count
for i in words:
    count_list += 1
    
# Use a for loop to insert the list words into the set
for word in words:
    words_set.add(word)
    
# Count the words in the set
count_set = len(words_set)

# Create a new dictionary to be able to count the instances of each word inside the list
word_freq = dict()

# This list is the one with punctuation
for word in words:
    word_freq[word] = (words.count(word))
    
# Use the string import to get a list of punctuation
punctuation_list =  list(string.punctuation)

# New list to hold those without punctuation
w_clean = list()

# For loop to check for length greater than 1 & to eliminate the punctuation
# in the first and last index of each word
for word in words:
    new_word = ""
    for char in word:
        if char[0] and char[-1] not in punctuation_list:
            new_word += char
            
    if len(new_word) > 0:
        w_clean.append(new_word)

# Count the words in the clean list
count_clean = len(w_clean)
        
# Print all of the variables with proper explanation for the user
print("The initial string:\n", s, "\n")
print("The lower cased string:\n", s_lower, "\n")
print("The list containing the punctuation from the string:\n", words, "\n")
print("The word count for the list is:\n", count_list, "\n")
print("The set containing the punctuation after list is inserted:\n", words_set, "\n")
print("The word count for the set is:\n", count_set, "\n")
print("The dictionary containing the distinct words and count frequency per word:\n", word_freq, "\n")
print("This is the list that does not contain punctuation in the first and last index:\n", w_clean, "\n" )
print("This is the count for the clean list:\n", count_clean, "\n")
# Out:
# The initial string:
#  Imagine a vast sheet of paper on which straight Lines, Triangles,
# Squares, Pentagons, Hexagons, and other figures, instead of remaining fixed
# in their places, move freely about, on or in the surface, but without the
# power of rising above or sinking below it, very much like shadows - only hard
# and with luminous edges - and you will then have a pretty correct notion of
# my country and countrymen. Alas, a few years ago, I should have said "my
# universe": but now my mind has been opened to higher views of things.
#
# The lower cased string:
#  imagine a vast sheet of paper on which straight lines, triangles,
# squares, pentagons, hexagons, and other figures, instead of remaining fixed
# in their places, move freely about, on or in the surface, but without the
# power of rising above or sinking below it, very much like shadows - only hard
# and with luminous edges - and you will then have a pretty correct notion of
# my country and countrymen. alas, a few years ago, i should have said "my
# universe": but now my mind has been opened to higher views of things.
#
# The list containing the punctuation from the string:
#  ['imagine', 'a', 'vast', 'sheet', 'of', 'paper', 'on', 'which', 'straight', 'lines,', 'triangles,', 'squares,', 'pentagons,', 'hexagons,', 'and', 'other', 'figures,', 'instead', 'of', 'remaining', 'fixed', 'in', 'their', 'places,', 'move', 'freely', 'about,', 'on', 'or', 'in', 'the', 'surface,', 'but', 'without', 'the', 'power', 'of', 'rising', 'above', 'or', 'sinking', 'below', 'it,', 'very', 'much', 'like', 'shadows', '-', 'only', 'hard', 'and', 'with', 'luminous', 'edges', '-', 'and', 'you', 'will', 'then', 'have', 'a', 'pretty', 'correct', 'notion', 'of', 'my', 'country', 'and', 'countrymen.', 'alas,', 'a', 'few', 'years', 'ago,', 'i', 'should', 'have', 'said', '"my', 'universe":', 'but', 'now', 'my', 'mind', 'has', 'been', 'opened', 'to', 'higher', 'views', 'of', 'things.']
#
# The word count for the list is:
#  92
#
# The set containing the punctuation after list is inserted:
#  {'edges', 'you', 'on', 'pretty', 'alas,', 'said', 'then', 'figures,', 'hexagons,', 'hard', 'lines,', 'luminous', 'mind', 'vast', 'have', 'rising', '-', 'correct', 'but', 'which', 'years', 'now', 'universe":', 'pentagons,', 'about,', 'few', 'i', 'been', 'remaining', 'or', 'a', 'will', 'and', 'sinking', 'move', 'my', 'above', 'squares,', 'fixed', 'their', 'in', 'power', '"my', 'higher', 'instead', 'below', 'notion', 'ago,', 'of', 'has', 'to', 'country', 'very', 'paper', 'should', 'sheet', 'much', 'triangles,', 'without', 'only', 'opened', 'things.', 'places,', 'the', 'surface,', 'freely', 'other', 'views', 'imagine', 'countrymen.', 'it,', 'straight', 'like', 'shadows', 'with'}
#
# The word count for the set is:
#  75
#
# The dictionary containing the distinct words and count frequency per word:
#  {'imagine': 1, 'a': 3, 'vast': 1, 'sheet': 1, 'of': 5, 'paper': 1, 'on': 2, 'which': 1, 'straight': 1, 'lines,': 1, 'triangles,': 1, 'squares,': 1, 'pentagons,': 1, 'hexagons,': 1, 'and': 4, 'other': 1, 'figures,': 1, 'instead': 1, 'remaining': 1, 'fixed': 1, 'in': 2, 'their': 1, 'places,': 1, 'move': 1, 'freely': 1, 'about,': 1, 'or': 2, 'the': 2, 'surface,': 1, 'but': 2, 'without': 1, 'power': 1, 'rising': 1, 'above': 1, 'sinking': 1, 'below': 1, 'it,': 1, 'very': 1, 'much': 1, 'like': 1, 'shadows': 1, '-': 2, 'only': 1, 'hard': 1, 'with': 1, 'luminous': 1, 'edges': 1, 'you': 1, 'will': 1, 'then': 1, 'have': 2, 'pretty': 1, 'correct': 1, 'notion': 1, 'my': 2, 'country': 1, 'countrymen.': 1, 'alas,': 1, 'few': 1, 'years': 1, 'ago,': 1, 'i': 1, 'should': 1, 'said': 1, '"my': 1, 'universe":': 1, 'now': 1, 'mind': 1, 'has': 1, 'been': 1, 'opened': 1, 'to': 1, 'higher': 1, 'views': 1, 'things.': 1}
#
# This is the list that does not contain punctuation in the first and last index:
#  ['imagine', 'a', 'vast', 'sheet', 'of', 'paper', 'on', 'which', 'straight', 'lines', 'triangles', 'squares', 'pentagons', 'hexagons', 'and', 'other', 'figures', 'instead', 'of', 'remaining', 'fixed', 'in', 'their', 'places', 'move', 'freely', 'about', 'on', 'or', 'in', 'the', 'surface', 'but', 'without', 'the', 'power', 'of', 'rising', 'above', 'or', 'sinking', 'below', 'it', 'very', 'much', 'like', 'shadows', 'only', 'hard', 'and', 'with', 'luminous', 'edges', 'and', 'you', 'will', 'then', 'have', 'a', 'pretty', 'correct', 'notion', 'of', 'my', 'country', 'and', 'countrymen', 'alas', 'a', 'few', 'years', 'ago', 'i', 'should', 'have', 'said', 'my', 'universe', 'but', 'now', 'my', 'mind', 'has', 'been', 'opened', 'to', 'higher', 'views', 'of', 'things']
#
# This is the count for the clean list:
#  90
