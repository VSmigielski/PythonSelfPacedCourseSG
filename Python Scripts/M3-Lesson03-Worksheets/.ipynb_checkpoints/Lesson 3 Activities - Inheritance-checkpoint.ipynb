# %% [markdown]
# # Lesson 3 Activities: Inheritance
# These activities will allow you to demonstrate your ability to:
# * Create new classes that inherit the attributes and methods of an existing class.
# * Define inherited classes that have different properties than their parent classes.
# * Use overriding to replace a property in a parent class with a property in an inherited class.

# %% [markdown]
# ## Activity 0
# Before beginning, create a class `Noun` to use as the starting point for the activities in this section. The `Noun` class can be anything you wish, as long as it meets the following criteria:
#
# * Do not use people or animals.
# * The category must be broad enough to include different examples of the category.
# * It must represent a real-life object.
#
# Include at least three attributes that are common to most (if not all) instances of the `Noun`. Use appropriate naming conventions. If you created a `Noun` class for an earlier activity in this course, you are welcome to use it for the activities in this page, or you can create a new one.
#
# Implement the appropriate `__init__` and `display` methods to create and display objects respectively.

# %%
# your code here
class Shape:
    color = ""
    shape = ""
    sides = ""
    def __init__(self, c,s,sd):
        self.color = c
        self.shape = s
        self.sides = sd
    def display(self):
        print("Shape's color: " + self.color)
        print("Shape's name: " + self.shape)
        print("Number of sides: " + self.sides)
    
shape_1 = Shape("multi", "circle", "none")

shape_1.display()

shape_2 = Shape("blue", "triangle", "3")

shape_2.display()

shape_3 = Shape("red", "square", "4")

shape_3.display()

shape_4 = Shape("green", "pentagon", "5")

shape_4.display()
# Out:
# Shape's color: multi
# Shape's name: circle
# Number of sides: none
# Shape's color: blue
# Shape's name: triangle
# Number of sides: 3
# Shape's color: red
# Shape's name: square
# Number of sides: 4
# Shape's color: green
# Shape's name: pentagon
# Number of sides: 5

# %% [markdown]
# ## Activity 1
# Use inheritance to create another class that will inherit from the `Noun` class. Create two objects using the new class and display each object's information using the `display` method.
#
# As an example from this lesson, we started with an `Animal` class, created a `Mammal` class that inherits from `Animal`, and then created two `Mammal` objects. You will need to identify an appropriate class based on your own `Noun` class as well as appropriate objects that represent the inherited class.

# %%
# your code here
class Shape:
    color = ""
    shape = ""
    sides = ""
    def __init__(self, c,s,sd):
        self.color = c
        self.shape = s
        self.sides = sd
    def display(self):
        print("Shape's color: " + self.color)
        print("Shape's name: " + self.shape)
        print("Number of sides: " + self.sides)
class Polygon(Shape):
    pass
    
shape_1 = Polygon("multi", "circle", "none")

shape_1.display()

shape_2 = Polygon("blue", "triangle", "3")

shape_2.display()
# Out:
# Shape's color: multi
# Shape's name: circle
# Number of sides: none
# Shape's color: blue
# Shape's name: triangle
# Number of sides: 3

# %% [markdown]
# ## Activity 2
# Add at least two attributes to the new class created in the previous activity. These attributes should be different from the attributes in the original `Noun` class and specific to the new class.
#
# > As an example from the lesson, the Animal class included the attributes of name and place. The Mammal class that inherits from the Animal class would include mammal-specific attributes, such as gender and fur length.
#
# Override the `__init__` and `display` methods to display the new attributes, and then create at least two new objects based on the inherited class and display them with the class attributes.

# %%
# your code here
class Shape:
    color = ""
    shape = ""
    sides = ""
    def __init__(self, c,s,sd):
        self.color = c
        self.shape = s
        self.sides = sd
    def display(self):
        print("Shape's color: " + self.color)
        print("Shape's name: " + self.shape)
        print("Number of sides: " + self.sides)
class Circle(Shape):
    radius = ""
    pi = ""
    area = ""
    def __init__(self, c, s, sd, r, p, a):
        Shape.__init__(self, c, s, sd)
        self.radius = r
        self.pi = p
        self.area = a
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Radius: " + self.radius)
        print("Pi: " + self.pi)
        print("Area: " + self.area)
    
shape_1 = Circle("multi", "circle", "none", "2", "3.14", "12.56")

shape_1.display()

shape_2 = Circle("blue", "circle", "none", "3", "3.14", "28.26")

shape_2.display()
# Out:
# Color: multi
# Shape: circle
# Sides: none
# Radius: 2
# Pi: 3.14
# Area: 12.56
# Color: blue
# Shape: circle
# Sides: none
# Radius: 3
# Pi: 3.14
# Area: 28.26

# %% [markdown]
# ## Activity 3
# Create a second and a third class that inherit from the `Noun` class you started with.
# * Include at least three class-specific attributes for each class.
#
# For each of the new classes, override the `__init__` and `display` methods to display the new attributes and then create at least two new objects based on the inherited class and display them with the class attributes.

# %%
# your code here
class Shape:
    color = ""
    shape = ""
    sides = ""
    def __init__(self, c,s,sd):
        self.color = c
        self.shape = s
        self.sides = sd
    def display(self):
        print("Shape's color: " + self.color)
        print("Shape's name: " + self.shape)
        print("Number of sides: " + self.sides)
class Circle(Shape):
    radius = ""
    pi = ""
    area = ""
    def __init__(self, c, s, sd, r, p, a):
        Shape.__init__(self, c, s, sd)
        self.radius = r
        self.pi = p
        self.area = a
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Radius: " + self.radius)
        print("Pi: " + self.pi)
        print("Area: " + self.area)
class Triangle(Shape):
    base = ""
    height = ""
    area = ""
    def __init__(self, c, s, sd, b, h, a):
        Shape.__init__(self, c, s, sd)
        self.base = b
        self.height = h
        self.area = a
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Base: " + self.base)
        print("Height: " + self.height)
        print("Area: " + self.area)
class Rectangle(Shape):
    length = ""
    width = ""
    area = ""
    def __init__(self, c, s, sd, l, w, a):
        Shape.__init__(self, c, s, sd)
        self.length = l
        self.width = w
        self.area = a
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Length: " + self.length)
        print("Width: " + self.width)
        print("Area: " + self.area)
    
shape_1 = Circle("multi", "circle", "none", "2", "3.14", "12.56")
shape_2 = Circle("blue", "circle", "none", "3", "3.14", "28.26")

shape_1.display()
shape_2.display()

shape_3 = Triangle("red", "triangle", "none", "2", "3", "3")
shape_4 = Triangle("green", "triangle", "none", "3", "3", "4.5")

shape_3.display()
shape_4.display()

shape_5 = Rectangle("orange", "rectangle", "none", "2", "3", "6")
shape_6 = Rectangle("pink", "rectangle", "none", "3", "3", "9")

shape_5.display()
shape_6.display()
# Out:
# Color: multi
# Shape: circle
# Sides: none
# Radius: 2
# Pi: 3.14
# Area: 12.56
# Color: blue
# Shape: circle
# Sides: none
# Radius: 3
# Pi: 3.14
# Area: 28.26
# Color: red
# Shape: triangle
# Sides: none
# Base: 2
# Height: 3
# Area: 3
# Color: green
# Shape: triangle
# Sides: none
# Base: 3
# Height: 3
# Area: 4.5
# Color: orange
# Shape: rectangle
# Sides: none
# Length: 2
# Width: 3
# Area: 6
# Color: pink
# Shape: rectangle
# Sides: none
# Length: 3
# Width: 3
# Area: 9

# %% [markdown]
# ## Activity 4
# Using the three inherited classes you have already created, use the `__init__` method of the `Noun` class to set the values of the original attributes defined in the `Noun` class.
#
# Create two objects for each of the three inherited classes and display all attributes, including attributes from the original `Noun` class.

# %%
# your code here
class Shape:
    color = ""
    shape = ""
    sides = ""
    def __init__(self, c,s,sd):
        self.color = c
        self.shape = s
        self.sides = sd
    def display(self):
        print("Shape's color: " + self.color)
        print("Shape's name: " + self.shape)
        print("Number of sides: " + self.sides)
class Circle(Shape):
    radius = ""
    pi = ""
    area = ""
    def __init__(self, c, s, sd, r, p, a):
        Shape.__init__(self, c, s, sd)
        self.radius = r
        self.pi = p
        self.area = a
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Radius: " + self.radius)
        print("Pi: " + self.pi)
        print("Area: " + self.area)
class Triangle(Shape):
    base = ""
    height = ""
    area = ""
    def __init__(self, c, s, sd, b, h, a):
        Shape.__init__(self, c, s, sd)
        self.base = b
        self.height = h
        self.area = a
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Base: " + self.base)
        print("Height: " + self.height)
        print("Area: " + self.area)
class Rectangle(Shape):
    length = ""
    width = ""
    area = ""
    def __init__(self, c, s, sd, l, w, a):
        Shape.__init__(self, c, s, sd)
        self.length = l
        self.width = w
        self.area = a
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Length: " + self.length)
        print("Width: " + self.width)
        print("Area: " + self.area)
    
shape_1 = Circle("multi", "circle", "none", "2", "3.14", "12.56")
shape_2 = Circle("blue", "circle", "none", "3", "3.14", "28.26")

shape_1.display()
shape_2.display()

shape_3 = Triangle("red", "triangle", "3", "2", "3", "3")
shape_4 = Triangle("green", "triangle", "3", "3", "3", "4.5")

shape_3.display()
shape_4.display()

shape_5 = Rectangle("orange", "rectangle", "4", "2", "3", "6")
shape_6 = Rectangle("pink", "rectangle", "4", "3", "3", "9")

shape_5.display()
shape_6.display()
# Out:
# Color: multi
# Shape: circle
# Sides: none
# Radius: 2
# Pi: 3.14
# Area: 12.56
# Color: blue
# Shape: circle
# Sides: none
# Radius: 3
# Pi: 3.14
# Area: 28.26
# Color: red
# Shape: triangle
# Sides: 3
# Base: 2
# Height: 3
# Area: 3
# Color: green
# Shape: triangle
# Sides: 3
# Base: 3
# Height: 3
# Area: 4.5
# Color: orange
# Shape: rectangle
# Sides: 4
# Length: 2
# Width: 3
# Area: 6
# Color: pink
# Shape: rectangle
# Sides: 4
# Length: 3
# Width: 3
# Area: 9

# %% [markdown]
# ## Activity 5
# Create a class that inherits from your initial inherited class. Include at least one attribute specific to this class.
#
# Create two objects based on this class and display all attributes for each object.
#
# > As an example from the lesson, we started with an `Animal` class and then created a `Mammal` class that inherits from `Animal`. We could have also created additional classes that inherit from `Mammal`, such as `Dog` and `Cat`, which would have their own class-specific attributes.

# %%
# your code here
class Shape:
    color = ""
    shape = ""
    sides = ""
    def __init__(self, c,s,sd):
        self.color = c
        self.shape = s
        self.sides = sd
    def display(self):
        print("Shape's color: " + self.color)
        print("Shape's name: " + self.shape)
        print("Number of sides: " + self.sides)
class Polygon(Shape):
    length = ""
    width = ""
    def __init__(self, c, s, sd, l, w):
        Shape.__init__(self, c, s, sd)
        self.length = l
        self.width = w
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Length: " + self.length)
        print("Width: " + self.width)
class Rectangle(Polygon):
    area = ""
    def __init__(self, c, s, sd, l, w, a):
        Polygon.__init__(self, c, s, sd, l, w)
        self.area = a
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Length: " + self.length)
        print("Width: " + self.width)
        print("Area: " + self.area)

shape_5 = Rectangle("orange", "rectangle", "4", "2", "3", "6")
shape_6 = Rectangle("pink", "rectangle", "4", "3", "3", "9")

shape_5.display()
shape_6.display()
# Out:
# Color: orange
# Shape: rectangle
# Sides: 4
# Length: 2
# Width: 3
# Area: 6
# Color: pink
# Shape: rectangle
# Sides: 4
# Length: 3
# Width: 3
# Area: 9

# %% [markdown]
# ## Activity 6
# Create another class that inherits from the class created for the previous activity. For the new class, create at least one class-specific attribute and one object based on the class.
#
# Use `isinstance()` to verify that the new object is an instance of each of the parent classes of the new class.

# %%
# your code here
class Shape:
    color = ""
    shape = ""
    sides = ""
    def __init__(self, c,s,sd):
        self.color = c
        self.shape = s
        self.sides = sd
    def display(self):
        print("Shape's color: " + self.color)
        print("Shape's name: " + self.shape)
        print("Number of sides: " + self.sides)
class Polygon(Shape):
    length = ""
    width = ""
    def __init__(self, c, s, sd, l, w):
        Shape.__init__(self, c, s, sd)
        self.length = l
        self.width = w
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Length: " + self.length)
        print("Width: " + self.width)
class Rectangle(Polygon):
    area = ""
    def __init__(self, c, s, sd, l, w, a):
        Polygon.__init__(self, c, s, sd, l, w)
        self.area = a
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Length: " + self.length)
        print("Width: " + self.width)
        print("Area: " + self.area)
        
class otherClass(Rectangle):
    random_att = ""
    def __init__(self, c, s, sd, l, w, a, ra):
        Rectangle.__init__(self, c, s, sd, l, w, a)
        self.random_att = ra
    def display(self):
        print("Color: " + self.color)
        print("Shape: " + self.shape)
        print("Sides: " + self.sides)
        print("Length: " + self.length)
        print("Width: " + self.width)
        print("Area: " + self.area)
        print("Random Attribute: " + self.random_att)

shape_5 = otherClass("orange", "rectangle", "4", "2", "3", "6", "random")
shape_6 = otherClass("pink", "rectangle", "4", "3", "3", "9", "idk")

shape_5.display()
shape_6.display()

print(isinstance(shape_5,Shape))
print(isinstance(shape_5,Polygon))
print(isinstance(shape_5,Rectangle))
print(isinstance(shape_5,otherClass))

print(isinstance(shape_6,Shape))
print(isinstance(shape_6,Polygon))
print(isinstance(shape_6,Rectangle))
print(isinstance(shape_6,otherClass))
# Out:
# Color: orange
# Shape: rectangle
# Sides: 4
# Length: 2
# Width: 3
# Area: 6
# Random Attribute: random
# Color: pink
# Shape: rectangle
# Sides: 4
# Length: 3
# Width: 3
# Area: 9
# Random Attribute: idk
# True
# True
# True
# True
# True
# True
# True
# True
