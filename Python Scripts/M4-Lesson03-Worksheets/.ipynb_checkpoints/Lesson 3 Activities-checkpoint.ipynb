# %% [markdown]
# # Lesson 3 Activities
# The exercises in this page will allow you to demonstrate your ability to:
# * Open, read, and display text-based files in .txt, .csv, and .json formats.
# * Append content to an existing file.
# * Replace data in an existing file with new data.
# * Use the Python `os` module to check for existing files.
#
# Unless otherwise specified, you may use any of the files provided in the course to complete these activities, create your own files, or find files that are available online.
#
# Most of these exercises can be completed using any text-based file, regardless of the file type. After creating the initial working code for one file type, try running the code on a different file type to see the result.

# %% [markdown]
# ## Activity 1
# Write a function that prompts the reader for an integer `n` and reads the first `n` lines of a file.
# Include a creative way to handle cases where `n` is greater than the number of lines available in the file.

# %%
# your code here
def count_lines(filepath):
    f = open(filepath, "r")
    count = 0
        
    for lines in f:
        count += 1
        
    return count

def head(filepath,num_lines):
    # remove pass and add code here
    f = open(filepath, "r")  
    line = ""
    
    count = count_lines(filepath)
    
    if count >= num_lines:
        for i in range(num_lines):
            line += f.readline()
    else:
        print("The file is not that long.")
        
    f.close() 
    
    return line

user_input = int(input("Enter the number of lines to read from the file:\n"))

text = head("FileIO-DataFiles/flatland01.txt", user_input) 
print(text)
# Out:
# Enter the number of lines to read from the file:
# 10
# FLATLAND
#
# PART 1
#
# THIS WORLD
#
# SECTION 1  Of the Nature of Flatland
#
# I call our world Flatland, not because we call it so, but to make its
# nature clearer to you, my happy readers, who are privileged to live in

# %% [markdown]
# ## Activity 2
# Write a function that takes as input the path to two text files and concatenates the files into a single new file.

# %%
# your code here
def merge_files(filepath1, filepath2, filepath3):
    data = data2 = ""

    with open(filepath1, 'r') as f:
        data = f.read()
    f.close()
    
    with open(filepath2, 'r') as f:
        data2 = f.read()
    f.close()
    
    data += "\n"
    data += data2
    
    new_file = filepath3
    
    with open (new_file, 'w') as f:
        f.write(data)
    f.close()
    
    return new_file
    
user_input1 = input("Enter a path and filename. Ex: FileIO-DataFiles/file1.txt\n")    
user_input2 = input("Enter a path and filename. Ex: FileIO-DataFiles/file1.txt\n")    
user_input3 = input("Enter a path and filename. Ex: FileIO-DataFiles/file1.txt\n")

new_file = merge_files(user_input1, user_input2, user_input3)

f = open(new_file, "r")  

print(f.read())

f.close()
# Out:
# Enter a path and filename. Ex: FileIO-DataFiles/file1.txt
# FileIO-DataFiles/file1.txt
# Enter a path and filename. Ex: FileIO-DataFiles/file1.txt
# FileIO-DataFiles/file2.txt
# Enter a path and filename. Ex: FileIO-DataFiles/file1.txt
# FileIO-DataFiles/file3.txt
# this is the first file
# this is the second file.

# %% [markdown]
# ## Activity 3
# Write a function that takes a variable number of text files and concatenates them into a single new file.

# %%
# your code here
def merge_many():
    filenames = []
  
    user_input = ""

    while user_input.lower() != "quit":
        user_input = input("Enter a path and filename. Ex: FileIO-DataFiles/file1.txt\n")
        if user_input.lower() != "quit":
            filenames.append(user_input)
        else:
            break

    user_input_file = input("Enter the file to merge into. Ex: FileIO-DataFiles/file4.txt\n")
    # Open file3 in write mode
    with open(user_input_file, 'w') as outfile:

        # Iterate through list
        for names in filenames:

            # Open each file in read mode
            with open(names) as infile:

                # read the data from file1 and
                # file2 and write it in file3
                outfile.write(infile.read())

            # Add '\n' to enter data of file2
            # from next line
            outfile.write("\n")
            
    outfile.close()
    
    return user_input_file

new_file = merge_many()

f = open(new_file, "r")  

print(f.read())

f.close()
# Out:
# Enter a path and filename. Ex: FileIO-DataFiles/file1.txt
# FileIO-DataFiles/file1.txt
# Enter a path and filename. Ex: FileIO-DataFiles/file1.txt
# FileIO-DataFiles/file2.txt
# Enter a path and filename. Ex: FileIO-DataFiles/file1.txt
# FileIO-DataFiles/file3.txt
# Enter a path and filename. Ex: FileIO-DataFiles/file1.txt
# quit
# Enter the file to merge into. Ex: FileIO-DataFiles/file4.txt
# FileIO-DataFiles/file4.txt
# this is the first file
# this is the second file.
# this is the first file
# this is the second file.

# %% [markdown]
# ## Activity 4
# Write a function that reads a text file line by line, stores each line in a list, and then returns the list.

# %%
# your code here
def head(filename):
    # remove pass and add code here
    with open(filename) as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
    content = [x.strip() for x in content]  
    
    f.close()
    return content

user_input = input("Enter a path and filename. Ex: FileIO-DataFiles/flatland01.txt\n")

new_list = head(user_input)

print(new_list)
# Out:
# Enter a path and filename. Ex: FileIO-DataFiles/flatland01.txt
# FileIO-DataFiles/flatland01.txt
# ['FLATLAND', '', 'PART 1', '', 'THIS WORLD', '', 'SECTION 1  Of the Nature of Flatland', '', 'I call our world Flatland, not because we call it so, but to make its', 'nature clearer to you, my happy readers, who are privileged to live in', 'Space.', '', 'Imagine a vast sheet of paper on which straight Lines, Triangles,', 'Squares, Pentagons, Hexagons, and other figures, instead of remaining', 'fixed in their places, move freely about, on or in the surface, but', 'without the power of rising above or sinking below it, very much like', 'shadows--only hard with luminous edges--and you will then have a pretty', 'correct notion of my country and countrymen.  Alas, a few years ago, I', 'should have said "my universe:"  but now my mind has been opened to', 'higher views of things.', '', 'In such a country, you will perceive at once that it is impossible that', 'there should be anything of what you call a "solid" kind; but I dare', 'say you will suppose that we could at least distinguish by sight the', 'Triangles, Squares, and other figures, moving about as I have described', 'them.  On the contrary, we could see nothing of the kind, not at least', 'so as to distinguish one figure from another.  Nothing was visible, nor', 'could be visible, to us, except Straight Lines; and the necessity of', 'this I will speedily demonstrate.']

# %% [markdown]
# ## Activity 5
# Write a function that takes as input the path to a text file and returns the longest word in the text file.

# %%
# your code here
def longest_word(filename):
    # remove pass and add code here
    with open(filename, 'r') as f:
        words = f.read().split()
    max_len = len(max(words, key=len))
    
    return [word for word in words if len(word) == max_len]

user_input = input("Enter a path and filename. Ex: FileIO-DataFiles/flatland01.txt\n")

word = longest_word(user_input)

print(word)
# Out:
# Enter a path and filename. Ex: FileIO-DataFiles/flatland01.txt
# FileIO-DataFiles/flatland01.txt
# ['shadows--only']

# %% [markdown]
# ## Activity 6
# Write a function that takes as input a list of strings and writes the list to a text file.
#
# Each element in the list should be a separate line in the new text file.

# %%
# your code here
def list_to_file(items, user_input):
    with open(user_input, 'w') as f:
        for listitem in items:
            f.write('%s\n' % listitem)
        
    f.close()
    return user_input

item_list = []

user_input_items = ""

user_input = input("Enter a path and filename where you want to save the information. Ex: FileIO-DataFiles/flatland01.txt\n")

while user_input_items.lower() != "quit":
    user_input_items = input("Enter a few items. \n")
    if user_input_items.lower() != "quit":
        item_list.append(user_input_items)
    else:
        break
        
new_file = list_to_file(item_list, user_input)

f = open(new_file, "r")  

print("\n")
print(f.read())

f.close()
# Out:
# Enter a path and filename where you want to save the information. Ex: FileIO-DataFiles/flatland01.txt
# FileIO-DataFiles/fruits.txt
# Enter a few inputs.
# kiwi
# Enter a few inputs.
# mango
# Enter a few inputs.
# strawberry
# Enter a few inputs.
# quit
#
#
# kiwi
# mango
# strawberry

# %% [markdown]
# ## Activity 7
# Write a function that takes as input a text file and a new filename, and then copies the contents of the input text file to another file using the new filename.
#
# **Challenge**: Update the code so that the lines in the new file are in the reverse order of the lines in the original file.

# %%
# your code here
def file_to_file(filepath1, filepath2):
    with open(filepath2, 'w') as outfile:
        with open(filepath1) as infile:
            lines = infile.readlines()
            for line in reversed(lines):
                outfile.write(line)
            
    outfile.close()
    
    return filepath2

filepath1 = input("Enter a path and filename where you want to retrieve information. Ex: FileIO-DataFiles/flatland01.txt\n")
filepath2 = input("Enter a path and filename where you want to save the information. Ex: FileIO-DataFiles/flatland01.txt\n")

file_created = file_to_file(filepath1, filepath2)

f = open(file_created, "r")  

print(f.read())

f.close()
# Out:
# Enter a path and filename where you want to retrieve information. Ex: FileIO-DataFiles/flatland01.txt
# FileIO-DataFiles/fruits.txt
# Enter a path and filename where you want to save the information. Ex: FileIO-DataFiles/flatland01.txt
# FileIO-DataFiles/fruits-reversed.txt
# strawberry
# mango
# kiwi

# %% [markdown]
# ## Activity 8
# Write a function that completes the following steps:
# * Open and read a CSV file.
# * Count the number of lines in the file.
# * Split the file into three separate CSV files so that each file includes approximately the same number of lines.
# * Reassemble the three CSV files into a new file with the pieces in a different order from the original.
#     * For example, if the original is split into Part 1, Part 2, and Part 3, the new file could contain the same content in the order Part 3, Part 1, Part 2.
#
# The code should be as automated as possible, so that the user simply has to identify the original file and does not need to know how many lines of text the file includes.

# %%
# your code here
import csv
def csv_into_three(filepath):
    with open(filepath) as f: 
        csv_file = csv.reader(f, delimiter=',')
        
        dataset = list()
        dataset1 = list()
        dataset2 = list()
        
        count = 0
        for row in csv_file:
            count += 1
            
            if count % 3 == 0:
                dataset.append(row)
            elif count % 3 == 1:
                dataset1.append(row)
            elif count % 3 == 2:
                dataset2.append(row)
            else: 
                pass
                
    f.close()
    
    fp1 = "FileIO-DataFiles/stocks-one.csv"
    fp2 = "FileIO-DataFiles/stocks-two.csv"
    fp3 = "FileIO-DataFiles/stocks-three.csv"
    
    write_csv(fp1, dataset)
    write_csv(fp2, dataset1)
    write_csv(fp3, dataset2)
    
    nf = "FileIO-DataFiles/stocks-together.csv"
    
    new_file = merge_many(fp3, fp1, fp2, nf)
    
    read_csv(new_file)

def read_csv(new_file):
    f = open(new_file, "r")  

    print(f.read())

    f.close() 
    
def merge_many(filepath1, filepath2, filepath3, new_file):
    filenames = [filepath1, filepath2, filepath3]
    
    with open(new_file, 'w') as outfile:

        # Iterate through list
        for names in filenames:

            # Open each file in read mode
            with open(names) as infile:

                # read the data from file1 and
                # file2 and write it in file3
                outfile.write(infile.read())
            
    outfile.close()
    
    return new_file
    
def write_csv(filepath, dataset): 
    with open(filepath, 'w') as f:
        writer = csv.writer(f,delimiter=',') 
        for i in dataset:
            writer.writerow(i)
        
    f.close()
    

csv_into_three("FileIO-DataFiles/stocks_short.csv")
# Out:
# 7/7/2006,492.7,495.9,490.0999,490.8,807950
#
# 7/12/2006,495.2,497.3,487.1001,488.3,1374150
#
# 7/17/2006,469.1,469.5,463.3,463.9999,3265409
#
# 7/20/2006,472.5,474.5,470.5,471.1,1597130
#
# 7/10/2006,493.3,496.4,491.0001,493.4,838869
#
# 7/13/2006,488,488,478.3,478.7,1633189
#
# 7/18/2006,464.2,468.9999,462.2,465.5,1655100
#
# Date,Open,High,Low,Close,Volume
#
# 7/11/2006,493.4,496.7999,488.6,496.0001,816880
#
# 7/14/2006,478.5001,480.0999,474.1,475.8,1539689
#
# 7/19/2006,468.5001,475.0999,468.3,472.5,2621339

# %% [markdown]
# ## Activity 9: Nobel Prizes
# For this activity, download and use the file [prize.json](https://the-software-guild.s3.amazonaws.com/techstart-1909/data-files/prize.json).
#
# This dataset includes information about Nobel Prizes, including the laureates who received each prize, when the prize was awarded, and the category of the prize.
#
# Write a program to analyze the data in this file to find the following information:
# 1. Identify the most recent year in the dataset where someone received a Nobel prize.
# 1. Identify the earliest year when someone received a Nobel prize.
# 1. Identify the category with the highest number of prizes.
# 1. Identify the laureate with the highest number of prizes.
# 1. Identify the laureate that won the most recent prize in peace.
# 1. Identify the laureate that won the most recent prize in medicine.
# 1. Identify the year when the most laureates jointly won the same prize in the same year.
# 1. How many prizes have been given in the economics category?
# 1. How many prizes have been given in peace?
# 1. How many prizes have been given in literature?
#
# **Tip**: Open the JSON file and examine it before starting this activity. This will help you identify where to find the data you need to answer the questions.

# %%
# your code here
import json
from pprint import pprint 
with open('FileIO-DataFiles/prizes.json','r') as jsonfile: 
    data = json.load(jsonfile)  
    
_min = 100000
_max = 0

for k in data['prizes']:
    for key, val in k.items():
        if key == "year":
            value = int(val)
            if value < _min:
                _min = value
            elif value > _max:
                _max = value
        else:
            pass
        
prizes = data['prizes']
new_dict = dict()

for prize in prizes:
    for k, v in prize.items():
        if k == "category" and v not in new_dict:
            new_dict[v] = 1
        elif k == "category" and v in new_dict:
            val = new_dict[v]
            val += 1
            new_dict[v] = val
        else:
            pass
        
new_dict2 = dict()

for prize in prizes:
    for k, v in prize.items():
        if k == "laureates":
            for d in v:
                # pprint(d)
                for key, values in d.items():
                    if key == "surname" and values not in new_dict2:
                        new_dict2[values] = 1
                        
                    elif key == "surname" and values in new_dict2:
                        new_value = new_dict2[values]
                        new_value += 1
                        new_dict2[values] = new_value
                    else:
                        pass

for k in data['prizes']:
    for key, val in k.items():
        if key == "category" and val == "peace":
            pprint(k)
        else:
            pass
        
for k in data['prizes']:
    for key, val in k.items():
        if key == "category" and val == "medicine":
            pprint(k)
        else:
            pass
        

 
for k, v in new_dict.items():
    if k == "economics":
        ecoK = k
        ecoV = v
    elif k == "peace":
        pK = k
        pV = v
    elif k == "literature":
        litK = k
        litV = v
    else:
        pass
        
# Identify the laureate that won the most recent prize in peace.
# Identify the laureate that won the most recent prize in medicine.
# Identify the year when the most laureates jointly won the same prize in the same year.        

print("The most recent year was", _max, "and the earliest year was", _min)
print("The most common category of Nobel prize is", max(new_dict), "with", new_dict[max(new_dict)], "occurences.")
print("The person who won the most is", max(new_dict2), "with", new_dict2[max(new_dict2)], ".")


print("The amount of prizes in the", ecoK, "category was", ecoV, ".")
print("The amount of prizes in the", pK, "category was", pV, ".")
print("The amount of prizes in the", litK, "category was", litV, ".")
# Out:
# {'category': 'peace',
#  'laureates': [{'firstname': 'International Campaign to Abolish Nuclear '
#                              'Weapons (ICAN)',
#                 'id': '948',
#                 'motivation': '"for its work to draw attention to the '
#                               'catastrophic humanitarian consequences of any '
#                               'use of nuclear weapons and for its '
#                               'ground-breaking efforts to achieve a '
#                               'treaty-based prohibition of such weapons"',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '2017'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Juan Manuel',
#                 'id': '934',
#                 'motivation': '"for his resolute efforts to bring the '
#                               "country's more than 50-year-long civil war to "
#                               'an end"',
#                 'share': '1',
#                 'surname': 'Santos'}],
#  'year': '2016'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'National Dialogue Quartet',
#                 'id': '925',
#                 'motivation': '"for its decisive contribution to the building '
#                               'of a pluralistic democracy in Tunisia in the '
#                               'wake of the Jasmine Revolution of 2011"',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '2015'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Kailash',
#                 'id': '913',
#                 'motivation': '"for their struggle against the suppression of '
#                               'children and young people and for the right of '
#                               'all children to education"',
#                 'share': '2',
#                 'surname': 'Satyarthi'},
#                {'firstname': 'Malala',
#                 'id': '914',
#                 'motivation': '"for their struggle against the suppression of '
#                               'children and young people and for the right of '
#                               'all children to education"',
#                 'share': '2',
#                 'surname': 'Yousafzai'}],
#  'year': '2014'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Organisation for the Prohibition of Chemical '
#                              'Weapons (OPCW)',
#                 'id': '893',
#                 'motivation': '"for its extensive efforts to eliminate '
#                               'chemical weapons"',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '2013'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'European Union (EU)',
#                 'id': '881',
#                 'motivation': '"for over six decades contributed to the '
#                               'advancement of peace and reconciliation, '
#                               'democracy and human rights in Europe"',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '2012'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Ellen',
#                 'id': '869',
#                 'motivation': '"for their non-violent struggle for the safety '
#                               'of women and for women&apos;s rights to full '
#                               'participation in peace-building work"',
#                 'share': '3',
#                 'surname': 'Johnson Sirleaf'},
#                {'firstname': 'Leymah',
#                 'id': '870',
#                 'motivation': '"for their non-violent struggle for the safety '
#                               'of women and for women&apos;s rights to full '
#                               'participation in peace-building work"',
#                 'share': '3',
#                 'surname': 'Gbowee'},
#                {'firstname': 'Tawakkol',
#                 'id': '871',
#                 'motivation': '"for their non-violent struggle for the safety '
#                               'of women and for women&apos;s rights to full '
#                               'participation in peace-building work"',
#                 'share': '3',
#                 'surname': 'Karman'}],
#  'year': '2011'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Liu',
#                 'id': '855',
#                 'motivation': '"for his long and non-violent struggle for '
#                               'fundamental human rights in China"',
#                 'share': '1',
#                 'surname': 'Xiaobo'}],
#  'year': '2010'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Barack H.',
#                 'id': '845',
#                 'motivation': '"for his extraordinary efforts to strengthen '
#                               'international diplomacy and cooperation between '
#                               'peoples"',
#                 'share': '1',
#                 'surname': 'Obama'}],
#  'year': '2009'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Martti',
#                 'id': '833',
#                 'motivation': '"for his important efforts, on several '
#                               'continents and over more than three decades, to '
#                               'resolve international conflicts"',
#                 'share': '1',
#                 'surname': 'Ahtisaari'}],
#  'year': '2008'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Intergovernmental Panel on Climate Change (IPCC)',
#                 'id': '818',
#                 'motivation': '"for their efforts to build up and disseminate '
#                               'greater knowledge about man-made climate '
#                               'change, and to lay the foundations for the '
#                               'measures that are needed to counteract such '
#                               'change"',
#                 'share': '2',
#                 'surname': ''},
#                {'firstname': 'Albert Arnold (Al)',
#                 'id': '819',
#                 'motivation': '"for their efforts to build up and disseminate '
#                               'greater knowledge about man-made climate '
#                               'change, and to lay the foundations for the '
#                               'measures that are needed to counteract such '
#                               'change"',
#                 'share': '2',
#                 'surname': 'Gore Jr.'}],
#  'year': '2007'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Muhammad',
#                 'id': '809',
#                 'motivation': '"for their efforts to create economic and '
#                               'social development from below"',
#                 'share': '2',
#                 'surname': 'Yunus'},
#                {'firstname': 'Grameen Bank',
#                 'id': '810',
#                 'motivation': '"for their efforts to create economic and '
#                               'social development from below"',
#                 'share': '2',
#                 'surname': ''}],
#  'year': '2006'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'International Atomic Energy Agency (IAEA)',
#                 'id': '797',
#                 'motivation': '"for their efforts to prevent nuclear energy '
#                               'from being used for military purposes and to '
#                               'ensure that nuclear energy for peaceful '
#                               'purposes is used in the safest possible way"',
#                 'share': '2',
#                 'surname': ''},
#                {'firstname': 'Mohamed',
#                 'id': '798',
#                 'motivation': '"for their efforts to prevent nuclear energy '
#                               'from being used for military purposes and to '
#                               'ensure that nuclear energy for peaceful '
#                               'purposes is used in the safest possible way"',
#                 'share': '2',
#                 'surname': 'ElBaradei'}],
#  'year': '2005'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Wangari Muta',
#                 'id': '783',
#                 'motivation': '"for her contribution to sustainable '
#                               'development, democracy and peace"',
#                 'share': '1',
#                 'surname': 'Maathai'}],
#  'year': '2004'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Shirin',
#                 'id': '773',
#                 'motivation': '"for her efforts for democracy and human '
#                               'rights. She has focused especially on the '
#                               'struggle for the rights of women and children"',
#                 'share': '1',
#                 'surname': 'Ebadi'}],
#  'year': '2003'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Jimmy',
#                 'id': '762',
#                 'motivation': '"for his decades of untiring effort to find '
#                               'peaceful solutions to international conflicts, '
#                               'to advance democracy and human rights, and to '
#                               'promote economic and social development"',
#                 'share': '1',
#                 'surname': 'Carter'}],
#  'year': '2002'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'United Nations (U.N.)',
#                 'id': '748',
#                 'motivation': '"for their work for a better organized and more '
#                               'peaceful world"',
#                 'share': '2',
#                 'surname': ''},
#                {'firstname': 'Kofi',
#                 'id': '749',
#                 'motivation': '"for their work for a better organized and more '
#                               'peaceful world"',
#                 'share': '2',
#                 'surname': 'Annan'}],
#  'year': '2001'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Kim',
#                 'id': '725',
#                 'motivation': '"for his work for democracy and human rights in '
#                               'South Korea and in East Asia in general, and '
#                               'for peace and reconciliation with North Korea '
#                               'in particular"',
#                 'share': '1',
#                 'surname': 'Dae-jung'}],
#  'year': '2000'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Médecins Sans Frontières',
#                 'id': '568',
#                 'motivation': '"in recognition of the organization\'s '
#                               'pioneering humanitarian work on several '
#                               'continents"',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1999'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'John',
#                 'id': '566',
#                 'motivation': '"for their efforts to find a peaceful solution '
#                               'to the conflict in Northern Ireland"',
#                 'share': '2',
#                 'surname': 'Hume'},
#                {'firstname': 'David',
#                 'id': '567',
#                 'motivation': '"for their efforts to find a peaceful solution '
#                               'to the conflict in Northern Ireland"',
#                 'share': '2',
#                 'surname': 'Trimble'}],
#  'year': '1998'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'International Campaign to Ban Landmines (ICBL)',
#                 'id': '564',
#                 'motivation': '"for their work for the banning and clearing of '
#                               'anti-personnel mines"',
#                 'share': '2',
#                 'surname': ''},
#                {'firstname': 'Jody',
#                 'id': '565',
#                 'motivation': '"for their work for the banning and clearing of '
#                               'anti-personnel mines"',
#                 'share': '2',
#                 'surname': 'Williams'}],
#  'year': '1997'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Carlos Filipe Ximenes',
#                 'id': '562',
#                 'motivation': '"for their work towards a just and peaceful '
#                               'solution to the conflict in East Timor"',
#                 'share': '2',
#                 'surname': 'Belo'},
#                {'firstname': 'José',
#                 'id': '563',
#                 'motivation': '"for their work towards a just and peaceful '
#                               'solution to the conflict in East Timor"',
#                 'share': '2',
#                 'surname': 'Ramos-Horta'}],
#  'year': '1996'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Joseph',
#                 'id': '560',
#                 'motivation': '"for their efforts to diminish the part played '
#                               'by nuclear arms in international politics and, '
#                               'in the longer run, to eliminate such arms"',
#                 'share': '2',
#                 'surname': 'Rotblat'},
#                {'firstname': 'Pugwash Conferences on Science and World Affairs',
#                 'id': '561',
#                 'motivation': '"for their efforts to diminish the part played '
#                               'by nuclear arms in international politics and, '
#                               'in the longer run, to eliminate such arms"',
#                 'share': '2',
#                 'surname': ''}],
#  'year': '1995'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Yasser',
#                 'id': '557',
#                 'motivation': '"for their efforts to create peace in the '
#                               'Middle East"',
#                 'share': '3',
#                 'surname': 'Arafat'},
#                {'firstname': 'Shimon',
#                 'id': '558',
#                 'motivation': '"for their efforts to create peace in the '
#                               'Middle East"',
#                 'share': '3',
#                 'surname': 'Peres'},
#                {'firstname': 'Yitzhak',
#                 'id': '559',
#                 'motivation': '"for their efforts to create peace in the '
#                               'Middle East"',
#                 'share': '3',
#                 'surname': 'Rabin'}],
#  'year': '1994'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Nelson',
#                 'id': '555',
#                 'motivation': '"for their work for the peaceful termination of '
#                               'the apartheid regime, and for laying the '
#                               'foundations for a new democratic South Africa"',
#                 'share': '2',
#                 'surname': 'Mandela'},
#                {'firstname': 'Frederik Willem',
#                 'id': '556',
#                 'motivation': '"for their work for the peaceful termination of '
#                               'the apartheid regime, and for laying the '
#                               'foundations for a new democratic South Africa"',
#                 'share': '2',
#                 'surname': 'de Klerk'}],
#  'year': '1993'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Rigoberta',
#                 'id': '554',
#                 'motivation': '"in recognition of her work for social justice '
#                               'and ethno-cultural reconciliation based on '
#                               'respect for the rights of indigenous peoples"',
#                 'share': '1',
#                 'surname': 'Menchú Tum'}],
#  'year': '1992'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Aung San Suu Kyi',
#                 'id': '553',
#                 'motivation': '"for her non-violent struggle for democracy and '
#                               'human rights"',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1991'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Mikhail Sergeyevich',
#                 'id': '552',
#                 'motivation': '"for his leading role in the peace process '
#                               'which today characterizes important parts of '
#                               'the international community"',
#                 'share': '1',
#                 'surname': 'Gorbachev'}],
#  'year': '1990'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'The 14th Dalai Lama (Tenzin Gyatso)',
#                 'id': '551',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1989'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'United Nations Peacekeeping Forces',
#                 'id': '550',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1988'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Oscar',
#                 'id': '549',
#                 'motivation': '"for his work for peace in Central America, '
#                               'efforts which led to the accord signed in '
#                               'Guatemala on August 7 this year"',
#                 'share': '1',
#                 'surname': 'Arias Sánchez'}],
#  'year': '1987'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Elie',
#                 'id': '548',
#                 'share': '1',
#                 'surname': 'Wiesel'}],
#  'year': '1986'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'International Physicians for the Prevention of '
#                              'Nuclear War',
#                 'id': '547',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1985'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Desmond Mpilo',
#                 'id': '546',
#                 'share': '1',
#                 'surname': 'Tutu'}],
#  'year': '1984'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Lech',
#                 'id': '545',
#                 'share': '1',
#                 'surname': 'Walesa'}],
#  'year': '1983'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Alva',
#                 'id': '543',
#                 'share': '2',
#                 'surname': 'Myrdal'},
#                {'firstname': 'Alfonso',
#                 'id': '544',
#                 'share': '2',
#                 'surname': 'García Robles'}],
#  'year': '1982'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Office of the United Nations High Commissioner '
#                              'for Refugees (UNHCR)',
#                 'id': '515',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1981'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Adolfo',
#                 'id': '541',
#                 'share': '1',
#                 'surname': 'Pérez Esquivel'}],
#  'year': '1980'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Mother Teresa',
#                 'id': '540',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1979'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Mohamed Anwar',
#                 'id': '538',
#                 'share': '2',
#                 'surname': 'al-Sadat'},
#                {'firstname': 'Menachem',
#                 'id': '539',
#                 'share': '2',
#                 'surname': 'Begin'}],
#  'year': '1978'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Amnesty International',
#                 'id': '537',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1977'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Betty',
#                 'id': '535',
#                 'share': '2',
#                 'surname': 'Williams'},
#                {'firstname': 'Mairead',
#                 'id': '536',
#                 'share': '2',
#                 'surname': 'Corrigan'}],
#  'year': '1976'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Andrei Dmitrievich',
#                 'id': '534',
#                 'share': '1',
#                 'surname': 'Sakharov'}],
#  'year': '1975'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Seán',
#                 'id': '532',
#                 'share': '2',
#                 'surname': 'MacBride'},
#                {'firstname': 'Eisaku',
#                 'id': '533',
#                 'share': '2',
#                 'surname': 'Sato'}],
#  'year': '1974'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Henry A.',
#                 'id': '530',
#                 'share': '2',
#                 'surname': 'Kissinger'},
#                {'firstname': 'Le Duc Tho',
#                 'id': '531',
#                 'share': '2',
#                 'surname': ''}],
#  'year': '1973'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Willy',
#                 'id': '529',
#                 'share': '1',
#                 'surname': 'Brandt'}],
#  'year': '1971'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Norman E.',
#                 'id': '528',
#                 'share': '1',
#                 'surname': 'Borlaug'}],
#  'year': '1970'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'International Labour Organization (I.L.O.)',
#                 'id': '527',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1969'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'René',
#                 'id': '526',
#                 'share': '1',
#                 'surname': 'Cassin'}],
#  'year': '1968'}
# {'category': 'peace',
#  'laureates': [{'firstname': "United Nations Children's Fund (UNICEF)",
#                 'id': '525',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1965'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Martin Luther',
#                 'id': '524',
#                 'share': '1',
#                 'surname': 'King Jr.'}],
#  'year': '1964'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Comité international de la Croix Rouge '
#                              '(International Committee of the Red Cross)',
#                 'id': '482',
#                 'share': '2',
#                 'surname': ''},
#                {'firstname': 'Ligue des Sociétés de la Croix-Rouge (League of '
#                              'Red Cross Societies)',
#                 'id': '523',
#                 'share': '2',
#                 'surname': ''}],
#  'year': '1963'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Linus Carl',
#                 'id': '217',
#                 'share': '1',
#                 'surname': 'Pauling'}],
#  'year': '1962'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Dag Hjalmar Agne Carl',
#                 'id': '520',
#                 'share': '1',
#                 'surname': 'Hammarskjöld'}],
#  'year': '1961'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Albert John',
#                 'id': '519',
#                 'share': '1',
#                 'surname': 'Lutuli'}],
#  'year': '1960'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Philip J.',
#                 'id': '518',
#                 'share': '1',
#                 'surname': 'Noel-Baker'}],
#  'year': '1959'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Georges',
#                 'id': '517',
#                 'share': '1',
#                 'surname': 'Pire'}],
#  'year': '1958'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Lester Bowles',
#                 'id': '516',
#                 'share': '1',
#                 'surname': 'Pearson'}],
#  'year': '1957'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Office of the United Nations High Commissioner '
#                              'for Refugees (UNHCR)',
#                 'id': '515',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1954'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'George Catlett',
#                 'id': '514',
#                 'share': '1',
#                 'surname': 'Marshall'}],
#  'year': '1953'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Albert',
#                 'id': '513',
#                 'share': '1',
#                 'surname': 'Schweitzer'}],
#  'year': '1952'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Léon',
#                 'id': '512',
#                 'share': '1',
#                 'surname': 'Jouhaux'}],
#  'year': '1951'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Ralph',
#                 'id': '511',
#                 'share': '1',
#                 'surname': 'Bunche'}],
#  'year': '1950'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Lord (John)',
#                 'id': '510',
#                 'share': '1',
#                 'surname': 'Boyd Orr of Brechin'}],
#  'year': '1949'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Friends Service Council (The Quakers)',
#                 'id': '508',
#                 'share': '2',
#                 'surname': ''},
#                {'firstname': 'American Friends Service Committee (The Quakers)',
#                 'id': '509',
#                 'share': '2',
#                 'surname': ''}],
#  'year': '1947'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Emily Greene',
#                 'id': '506',
#                 'share': '2',
#                 'surname': 'Balch'},
#                {'firstname': 'John Raleigh',
#                 'id': '507',
#                 'share': '2',
#                 'surname': 'Mott'}],
#  'year': '1946'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Cordell',
#                 'id': '505',
#                 'share': '1',
#                 'surname': 'Hull'}],
#  'year': '1945'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Comité international de la Croix Rouge '
#                              '(International Committee of the Red Cross)',
#                 'id': '482',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1944'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Office international Nansen pour les Réfugiés '
#                              '(Nansen International Office for Refugees)',
#                 'id': '503',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1938'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Cecil of Chelwood, Viscount',
#                 'id': '502',
#                 'share': '1',
#                 'surname': '(Lord Edgar Algernon Robert Gascoyne Cecil)'}],
#  'year': '1937'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Carlos',
#                 'id': '501',
#                 'share': '1',
#                 'surname': 'Saavedra Lamas'}],
#  'year': '1936'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Carl',
#                 'id': '500',
#                 'share': '1',
#                 'surname': 'von Ossietzky'}],
#  'year': '1935'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Arthur',
#                 'id': '499',
#                 'share': '1',
#                 'surname': 'Henderson'}],
#  'year': '1934'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Sir Norman',
#                 'id': '498',
#                 'share': '1',
#                 'surname': 'Angell (Ralph Lane)'}],
#  'year': '1933'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Jane',
#                 'id': '496',
#                 'share': '2',
#                 'surname': 'Addams'},
#                {'firstname': 'Nicholas Murray',
#                 'id': '497',
#                 'share': '2',
#                 'surname': 'Butler'}],
#  'year': '1931'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Lars Olof Jonathan (Nathan)',
#                 'id': '495',
#                 'share': '1',
#                 'surname': 'Söderblom'}],
#  'year': '1930'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Frank Billings',
#                 'id': '494',
#                 'share': '1',
#                 'surname': 'Kellogg'}],
#  'year': '1929'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Ferdinand',
#                 'id': '492',
#                 'share': '2',
#                 'surname': 'Buisson'},
#                {'firstname': 'Ludwig',
#                 'id': '493',
#                 'share': '2',
#                 'surname': 'Quidde'}],
#  'year': '1927'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Aristide',
#                 'id': '490',
#                 'share': '2',
#                 'surname': 'Briand'},
#                {'firstname': 'Gustav',
#                 'id': '491',
#                 'share': '2',
#                 'surname': 'Stresemann'}],
#  'year': '1926'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Sir Austen',
#                 'id': '488',
#                 'share': '2',
#                 'surname': 'Chamberlain'},
#                {'firstname': 'Charles Gates',
#                 'id': '489',
#                 'share': '2',
#                 'surname': 'Dawes'}],
#  'year': '1925'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Fridtjof',
#                 'id': '487',
#                 'share': '1',
#                 'surname': 'Nansen'}],
#  'year': '1922'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Karl Hjalmar',
#                 'id': '485',
#                 'share': '2',
#                 'surname': 'Branting'},
#                {'firstname': 'Christian Lous',
#                 'id': '486',
#                 'share': '2',
#                 'surname': 'Lange'}],
#  'year': '1921'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Léon Victor Auguste',
#                 'id': '484',
#                 'share': '1',
#                 'surname': 'Bourgeois'}],
#  'year': '1920'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Thomas Woodrow',
#                 'id': '483',
#                 'share': '1',
#                 'surname': 'Wilson'}],
#  'year': '1919'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Comité international de la Croix Rouge '
#                              '(International Committee of the Red Cross)',
#                 'id': '482',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1917'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Henri',
#                 'id': '481',
#                 'share': '1',
#                 'surname': 'La Fontaine'}],
#  'year': '1913'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Elihu',
#                 'id': '480',
#                 'share': '1',
#                 'surname': 'Root'}],
#  'year': '1912'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Tobias Michael Carel',
#                 'id': '478',
#                 'share': '2',
#                 'surname': 'Asser'},
#                {'firstname': 'Alfred Hermann',
#                 'id': '479',
#                 'share': '2',
#                 'surname': 'Fried'}],
#  'year': '1911'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Bureau international permanent de la Paix '
#                              '(Permanent International Peace Bureau)',
#                 'id': '477',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1910'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Auguste Marie François',
#                 'id': '475',
#                 'share': '2',
#                 'surname': 'Beernaert'},
#                {'firstname': 'Paul Henri Benjamin Balluet',
#                 'id': '476',
#                 'share': '2',
#                 'surname': "d'Estournelles de Constant, Baron de Constant de "
#                            'Rebecque'}],
#  'year': '1909'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Klas Pontus',
#                 'id': '473',
#                 'share': '2',
#                 'surname': 'Arnoldson'},
#                {'firstname': 'Fredrik',
#                 'id': '474',
#                 'share': '2',
#                 'surname': 'Bajer'}],
#  'year': '1908'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Ernesto Teodoro',
#                 'id': '471',
#                 'share': '2',
#                 'surname': 'Moneta'},
#                {'firstname': 'Louis',
#                 'id': '472',
#                 'share': '2',
#                 'surname': 'Renault'}],
#  'year': '1907'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Theodore',
#                 'id': '470',
#                 'share': '1',
#                 'surname': 'Roosevelt'}],
#  'year': '1906'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Baroness Bertha Sophie Felicita',
#                 'id': '468',
#                 'share': '1',
#                 'surname': 'von Suttner, née Countess Kinsky von Chinic und '
#                            'Tettau'}],
#  'year': '1905'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Institut de droit international (Institute of '
#                              'International Law)',
#                 'id': '467',
#                 'share': '1',
#                 'surname': ''}],
#  'year': '1904'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'William Randal',
#                 'id': '466',
#                 'share': '1',
#                 'surname': 'Cremer'}],
#  'year': '1903'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Élie',
#                 'id': '464',
#                 'share': '2',
#                 'surname': 'Ducommun'},
#                {'firstname': 'Charles Albert',
#                 'id': '465',
#                 'share': '2',
#                 'surname': 'Gobat'}],
#  'year': '1902'}
# {'category': 'peace',
#  'laureates': [{'firstname': 'Jean Henry',
#                 'id': '462',
#                 'share': '2',
#                 'surname': 'Dunant'},
#                {'firstname': 'Frédéric',
#                 'id': '463',
#                 'share': '2',
#                 'surname': 'Passy'}],
#  'year': '1901'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-e309ae1ac6a2> in <module>
#      61     for key, val in k.items():
#      62         if key == "category" and val == "medicine":
# ---> 63             this_dict = {k}
#      64         else:
#      65             pass
#
# TypeError: unhashable type: 'dict'

# %% [markdown]
# ## Activity 10: New York Restaurants
# For this activity, use the file [restaurant.json](https://the-software-guild.s3.amazonaws.com/techstart-1909/data-files/restaurant.json); download it if you do not already have a copy.
#
# This dataset includes records of restaurants in New York City, including where each restaurant is located, what kind of cuisine it serves, and its customer ratings. Here is a sample record:
#
#
#     {"address": {"building": "1007", "coord": [-73.856077, 40.848447], "street": "Morris Park Ave", "zipcode": "10462"}, "borough": "Bronx", "cuisine": "Bakery", "grades": [{"date": {"$date": 1393804800000}, "grade": "A", "score": 2}, {"date": {"$date": 1378857600000}, "grade": "A", "score": 6}, {"date": {"$date": 1358985600000}, "grade": "A", "score": 10}, {"date": {"$date": 1322006400000}, "grade": "A", "score": 9}, {"date": {"$date": 1299715200000}, "grade": "B", "score": 14}], "name": "Morris Park Bake Shop", "restaurant_id": "30075445"}
#
# Use Python to analyze the data in this file and find the following information:
# 1. Compute the average score for each restaurant.
# 1. Compute the minimum score for each restaurant.
# 1. Compute the maximum score for each restaurant.
# 1. Compute the average score for each type of cuisine in each borough.
# 1. Compute the minimum score for each type of cuisine in each borough.
# 1. Compute the maximum score for each type of cuisine in each borough.

# %%
# your code here
import json
# we use pprint to display json/dictionary objects in a human readable format
from pprint import pprint 
 
with open('FileIO-DataFiles/restaurant-1.json','r') as jsonfile: # use open to read the file
    # use the json module with the load function 
    # to read the content of the json file into a dictionary
    data = json.load(jsonfile) # load the json content and serialize it.
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-124-bc6e7d837703> in <module>
#       7     # use the json module with the load function
#       8     # to read the content of the json file into a dictionary
# ----> 9     data = json.load(jsonfile) # load the json content and serialize it.
#      10
#
# ~\anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 2 column 1 (char 544)

# %% [markdown]
# ## Activity 11: Pop Music Evolution
# For this exercise, use the *evolutionPopUSA_MainData.csv* file, which you can find on [Figshare](https://figshare.com/articles/Main_Dataset_for_Evolution_of_Popular_Music_USA_1960_2010_/1309953). Take some time to review the information about the dataset on that page before completing this activity.
#
# Write a program to read the collection and find the following information:
# 1. Find out if there are any artists that had songs in the Pop USA playlist in two different decades.
# 1. Identify the artist with the most songs in the Pop USA playlist.
# 1. Identify the cluster with the most songs.
# 1. Identify the genres within each cluster.
# 1. Identify the era with the most songs.

# %%
# your code here
import csv

with open('FileIO-DataFiles/EvolutionPopUSA_MainData.csv') as f: 
    csv_file = csv.reader(f, delimiter=',')
    
    for row in csv_file:
        print(row)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
